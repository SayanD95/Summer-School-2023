# %%
import pandas as pd
import numpy as np
import copy

# %%
df = pd.read_csv('data/data.csv') # reading data frame

# %%
df
# Out:
#      S.No    EmpID Emp Name        DOJ                 Designation Grade  \
# 0       1  XYZ2685     ABC1  22-Nov-10             Sales Executive    E1
# 1       2  XYZ2490     ABC2   5-Jul-10  Technical Services Officer    M2
# 2       3  XYZ2662     ABC3  20-Oct-10             Sales Executive    E1
# 3       4  XYZ1679     ABC4   1 May 08                  AM - Sales    M1
# 4       5  XYZ2378     ABC5   3 Mar 10            Sales Executive     E1
# ..    ...      ...      ...        ...                         ...   ...
# 322   323  XYZ1538   ABC323  26-May-08                  AM - Sales    M1
# 323   324  XYZ3221   ABC324  13-Sep-12             Sales Executive    E1
# 324   325  XYZ0207   ABC325  12-Dec-05          Sr Sales Executive    E2
# 325   326  XYZ0183   ABC326  21-Jul-04                  AM - Sales    M1
# 326   327  XYZ3381   ABC327  22-Feb-13             Sales Executive    E1
#
#     Attrition        Location In Active Date  Tenure  Gender  Education  Age  \
# ...

# %% [markdown]
# ## Male employee resignations

# %%
df_male=(df.loc[df["Gender"]=="Male"])
df_male
# Out:
#      S.No    EmpID Emp Name        DOJ                 Designation Grade  \
# 1       2  XYZ2490     ABC2   5-Jul-10  Technical Services Officer    M2
# 2       3  XYZ2662     ABC3  20-Oct-10             Sales Executive    E1
# 3       4  XYZ1679     ABC4   1 May 08                  AM - Sales    M1
# 4       5  XYZ2378     ABC5   3 Mar 10            Sales Executive     E1
# 5       6  XYZ3009     ABC6  17 Nov 11             Sales Executive    E1
# ..    ...      ...      ...        ...                         ...   ...
# 322   323  XYZ1538   ABC323  26-May-08                  AM - Sales    M1
# 323   324  XYZ3221   ABC324  13-Sep-12             Sales Executive    E1
# 324   325  XYZ0207   ABC325  12-Dec-05          Sr Sales Executive    E2
# 325   326  XYZ0183   ABC326  21-Jul-04                  AM - Sales    M1
# 326   327  XYZ3381   ABC327  22-Feb-13             Sales Executive    E1
#
#     Attrition        Location In Active Date  Tenure Gender  Education  Age  \
# ...

# %%
df_age = df_male.sort_values(["Age"], ascending = True) #sorts all data based on Age values, in ascending order.
df_age
# Out:
#      S.No    EmpID Emp Name          DOJ                 Designation Grade  \
# 211   212  XYZ2597   ABC212     1-Sep-10             Sales Executive    E1
# 283   284  XYZ3270   ABC284  14-Nov-2012             Sales Executive    E1
# 178   179  XYZ2832   ABC179    28-Mar-11             Sales Executive    E1
# 179   180  XYZ3052   ABC180    13-Feb-12             Sales Executive    E1
# 89     90  XYZ2249    ABC90     7 Dec 09             Sales Executive    E1
# ..    ...      ...      ...          ...                         ...   ...
# 168   169  XYZ2833   ABC169    28-Mar-11  Technical Services Officer    M2
# 140   141  XYZ3007   ABC141     1 Jul 12  Technical Services Officer    M2
# 120   121  XYZ0764   ABC121   12-03-2004  Technical Services Officer    M2
# 81     82  XYZ2633    ABC82   02-09-2010               Zonal Manager    M4
# 196   197  XYZ2728   ABC197    22-Dec-10         National Sales Head   CXO
#
# ...

# %%
df.loc[df["Grade"].str.contains("E1")]
# Out:
#      S.No    EmpID Emp Name        DOJ       Designation Grade Attrition   \
# 0       1  XYZ2685     ABC1  22-Nov-10   Sales Executive    E1        Yes
# 2       3  XYZ2662     ABC3  20-Oct-10   Sales Executive    E1        Yes
# 4       5  XYZ2378     ABC5   3 Mar 10  Sales Executive     E1        Yes
# 5       6  XYZ3009     ABC6  17 Nov 11   Sales Executive    E1        Yes
# 6       7  XYZ2783     ABC7   7 Feb 11  Sales Executive     E1        Yes
# ..    ...      ...      ...        ...               ...   ...        ...
# 319   320  XYZ3059   ABC320  27-Feb-12   Sales Executive    E1        Yes
# 320   321  XYZ3106   ABC321   6-Apr-12   Sales Executive    E1        Yes
# 321   322  XYZ3159   ABC322  18-Jun-12   Sales Executive    E1        Yes
# 323   324  XYZ3221   ABC324  13-Sep-12   Sales Executive    E1        Yes
# 326   327  XYZ3381   ABC327  22-Feb-13   Sales Executive    E1        Yes
#
#          Location In Active Date  Tenure  Gender  Education  Age  Last Rating  \
# ...

# %%
from matplotlib import pyplot as plt
import matplotlib.image as img
import matplotlib

# %%
df_designation = df.loc[df["Designation"]=="Sales Executive"]
df_designation
# Out:
#      S.No    EmpID Emp Name        DOJ      Designation Grade Attrition   \
# 0       1  XYZ2685     ABC1  22-Nov-10  Sales Executive    E1        Yes
# 2       3  XYZ2662     ABC3  20-Oct-10  Sales Executive    E1        Yes
# 5       6  XYZ3009     ABC6  17 Nov 11  Sales Executive    E1        Yes
# 7       8  XYZ2657     ABC8  20 Oct 10  Sales Executive    E1        Yes
# 8       9  XYZ3046     ABC9   1 Feb 12  Sales Executive    E1        Yes
# ..    ...      ...      ...        ...              ...   ...        ...
# 319   320  XYZ3059   ABC320  27-Feb-12  Sales Executive    E1        Yes
# 320   321  XYZ3106   ABC321   6-Apr-12  Sales Executive    E1        Yes
# 321   322  XYZ3159   ABC322  18-Jun-12  Sales Executive    E1        Yes
# 323   324  XYZ3221   ABC324  13-Sep-12  Sales Executive    E1        Yes
# 326   327  XYZ3381   ABC327  22-Feb-13  Sales Executive    E1        Yes
#
#          Location In Active Date  Tenure  Gender  Education  Age  Last Rating  \
# ...

# %%
df_Tenure_male = df_male.sort_values(["Tenure"], ascending = False) #sorts all data based on Age values, in ascending order.
df_test = df_Tenure_male.sort_values(["Monthly Income"], ascending = False)
df_test
# Out:
#      S.No    EmpID Emp Name         DOJ                 Designation Grade  \
# 196   197  XYZ2728   ABC197   22-Dec-10         National Sales Head   CXO
# 81     82  XYZ2633    ABC82  02-09-2010               Zonal Manager    M4
# 171   172  XYZ2231   ABC172   14-Dec-08               Zonal Manager    M4
# 217   218  XYZ0620   ABC218   24-Oct-06            Regional Manager    M3
# 193   194  XYZ3213   ABC194    1-Sep-12  Technical Services Officer    M2
# ..    ...      ...      ...         ...                         ...   ...
# 135   136  XYZ2350   ABC136   15-Feb-10            Sales Executive     E1
# 290   291  XYZ3305   ABC291    6-Dec-12             Sales Executive    E1
# 229   230  XYZ2529   ABC230   21-Jul-10             Sales Executive    E1
# 104   105  XYZ3062   ABC105   24 Feb 12             Sales Executive    E1
# 47     48  XYZ1631    ABC48    7 Jun 08             Sales Executive    E1
#
#     Attrition       Location In Active Date  Tenure Gender  Education  Age  \
# ...

# %%
df_designation = df_test.loc[df_test["Designation"]=="Sales Executive"]
df_designation_Tenure = df_test.loc[df_test["Grade"]=="M1"]
df_designation_Tenure
df_test1 = df_designation_Tenure.sort_values(["Tenure"], ascending=True)
df_test1
# Out:
#      S.No    EmpID Emp Name        DOJ Designation Grade Attrition   \
# 269   270  XYZ3321   ABC270  27-Dec-12  AM - Sales    M1        Yes
# 49     50  XYZ2911    ABC50  25 May 12  AM - Sales    M1        Yes
# 315   316  XYZ3111   ABC316  23-Apr-12  AM - Sales    M1        Yes
# 214   215  XYZ3170   ABC215   2-Jul-12  AM - Sales    M1        Yes
# 72     73  XYZ3056    ABC73  23 Feb 12  AM - Sales    M1        Yes
# 253   254  XYZ0054   ABC254   4-Aug-12  AM - Sales    M1        Yes
# 177   178  XYZ3100   ABC178  16-Apr-12  AM - Sales    M1        Yes
# 183   184  XYZ3069   ABC184   1-Mar-12  AM - Sales    M1        Yes
# 29     30  XYZ2853    ABC30   5 Apr 11  AM - Sales    M1        Yes
# 216   217  XYZ2334   ABC217  24-Feb-10  AM - Sales    M1        Yes
# 28     29  XYZ1636    ABC29   2 Jun 08  AM - Sales    M1        Yes
# 3       4  XYZ1679     ABC4   1 May 08  AM - Sales    M1        Yes
# 172   173  XYZ1341   ABC173   1-Mar-08  AM - Sales    M1        Yes
# ...

# %%
df
# Out:
#      S.No    EmpID Emp Name        DOJ                 Designation Grade  \
# 0       1  XYZ2685     ABC1  22-Nov-10             Sales Executive    E1
# 1       2  XYZ2490     ABC2   5-Jul-10  Technical Services Officer    M2
# 2       3  XYZ2662     ABC3  20-Oct-10             Sales Executive    E1
# 3       4  XYZ1679     ABC4   1 May 08                  AM - Sales    M1
# 4       5  XYZ2378     ABC5   3 Mar 10            Sales Executive     E1
# ..    ...      ...      ...        ...                         ...   ...
# 322   323  XYZ1538   ABC323  26-May-08                  AM - Sales    M1
# 323   324  XYZ3221   ABC324  13-Sep-12             Sales Executive    E1
# 324   325  XYZ0207   ABC325  12-Dec-05          Sr Sales Executive    E2
# 325   326  XYZ0183   ABC326  21-Jul-04                  AM - Sales    M1
# 326   327  XYZ3381   ABC327  22-Feb-13             Sales Executive    E1
#
#     Attrition        Location In Active Date  Tenure  Gender  Education  Age  \
# ...

# %%
list(df.columns)
# Out:
# ['S.No',
#  'EmpID',
#  'Emp Name',
#  'DOJ',
#  'Designation',
#  'Grade',
#  'Attrition ',
#  'Location',
#  'In Active Date',
#  'Tenure',
#  'Gender',
#  'Education',
#  'Age',
#  'Last Rating',
#  'Monthly Income',
#  'Engagement Score (% Satisfaction)',
#  'Marital Status',
#  'Zone',
#  'Remarks']

# %%
df["Age"][1:10]
# Out:
# 1    36
# 2    24
# 3    33
# 4    24
# 5    26
# 6    24
# 7    27
# 8    26
# 9    26
# Name: Age, dtype: int64

# %% [markdown]
# ## Employees of Grade `M1` in descending order of `Last Rating`

# %%
df2 = df.loc[df["Grade"]=="M1"]
df2.sort_values(["Last Rating"], ascending = False)
# Out:
#      S.No    EmpID Emp Name        DOJ Designation Grade Attrition   \
# 269   270  XYZ3321   ABC270  27-Dec-12  AM - Sales    M1        Yes
# 172   173  XYZ1341   ABC173   1-Mar-08  AM - Sales    M1        Yes
# 249   250  XYZ1414   ABC250  13-Mar-08  AM - Sales    M1        Yes
# 216   217  XYZ2334   ABC217  24-Feb-10  AM - Sales    M1        Yes
# 214   215  XYZ3170   ABC215   2-Jul-12  AM - Sales    M1        Yes
# 130   131  XYZ0152   ABC131  18 Dec 06  AM - Sales    M1        Yes
# 183   184  XYZ3069   ABC184   1-Mar-12  AM - Sales    M1        Yes
# 176   177  XYZ0341   ABC177  15-Oct-06  AM - Sales    M1        Yes
# 325   326  XYZ0183   ABC326  21-Jul-04  AM - Sales    M1        Yes
# 74     75  XYZ2415    ABC75   6 May 10  AM - Sales    M1        Yes
# 72     73  XYZ3056    ABC73  23 Feb 12  AM - Sales    M1        Yes
# 29     30  XYZ2853    ABC30   5 Apr 11  AM - Sales    M1        Yes
# 164   165  XYZ0524   ABC165  15-Dec-05  AM - Sales    M1        Yes
# ...

# %% [markdown]
# ## Employees in `Velachery` who have `Last Rating` more than `4`

# %%
df3 = df.loc[(df["Location"]=="Velachery") & (df["Last Rating"]>=4)]
df3.sort_values(["Tenure"], ascending=True)
# Out:
#      S.No    EmpID Emp Name        DOJ                 Designation Grade  \
# 175   176  XYZ3089   ABC176  22-Mar-12  Technical Services Officer    M2
# 216   217  XYZ2334   ABC217  24-Feb-10                  AM - Sales    M1
# 88     89  XYZ1755    ABC89   1 Aug 08            Sales Executive     E1
#
#     Attrition    Location In Active Date  Tenure Gender  Education  Age  \
# 175        Yes  Velachery      27 Sep 12   0. 6    Male  Bachelors   41
# 216        Yes  Velachery      14 Nov 12   2 .8    Male  Bachelors   34
# 88         Yes  Velachery      31 Jul 12  3 .11    Male  Bachelors   28
#
#      Last Rating  Monthly Income Engagement Score (% Satisfaction)  \
# 175            4           55757                               37%
# 216            4           50040                               26%
# 88             4           25248                               51%
#
#     Marital Status   Zone                                         Remarks
# ...
